# %%
import pandas as pd

# %%
data = pd.read_csv("data/customer_data.csv")
data.head()
# Out:
#    customer_id  age  gender  tenure_months   contract_type  monthly_charges  \
# 0            1   42  Female             24  Month-to-month            74.35
# 1            2   28    Male              6  Month-to-month            60.15
# 2            3   57    Male             36        One year            82.55
# 3            4   35  Female             12  Month-to-month            55.25
# 4            5   61  Female             58        Two year            92.85
#
#    total_charges internet_service phone_service multiple_lines  ...  \
# 0        1788.45      Fiber optic           Yes            Yes  ...
# 1         371.85      Fiber optic           Yes             No  ...
# 2        2927.85      Fiber optic           Yes             No  ...
# 3         671.75              DSL           Yes             No  ...
# 4        5293.30      Fiber optic           Yes            Yes  ...
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# ...

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'tenure_months', 'contract_type',
#        'monthly_charges', 'total_charges', 'internet_service', 'phone_service',
#        'multiple_lines', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'paperless_billing', 'payment_method', 'monthly_usage_gb',
#        'customer_service_calls', 'churn'],
#       dtype='str')

# %%
data["tenure_months"] = data["tenure_months"].fillna(data["tenure_months"].mean())
data["monthly_charges"] = data["monthly_charges"].fillna(data["monthly_charges"].mean())
data["total_charges"] = data["total_charges"].fillna(data["total_charges"].mean())

# %%
data.head()
# Out:
#    customer_id  age  gender  tenure_months   contract_type  monthly_charges  \
# 0            1   42  Female             24  Month-to-month            74.35
# 1            2   28    Male              6  Month-to-month            60.15
# 2            3   57    Male             36        One year            82.55
# 3            4   35  Female             12  Month-to-month            55.25
# 4            5   61  Female             58        Two year            92.85
#
#    total_charges internet_service phone_service multiple_lines  ...  \
# 0        1788.45      Fiber optic           Yes            Yes  ...
# 1         371.85      Fiber optic           Yes             No  ...
# 2        2927.85      Fiber optic           Yes             No  ...
# 3         671.75              DSL           Yes             No  ...
# 4        5293.30      Fiber optic           Yes            Yes  ...
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# ...

# %%
### Erlang C, Supongamos hay 100 agentes y el Shrinkage es del 30 porciento
# Entonces necesitariamos
# 100/(1-0.3)=143 agentes

# aht = total tiempo / llamadas atendidas


def erlang(transaction: int, aht: int) -> int:
    #TODO
    return 0
# Out:
#   Cell In[17], line 2
#     Erlang C
#            ^
# SyntaxError: invalid syntax
